# %%
import pandas as pd
print(pd.__version__)
# Out:
# 2.3.3

# %%
df= pd.read_csv('personas.csv', sep=';')

#Ver primeras filas
print(df.head())
# Out:
#    Nombre  Edad     Ciudad
# 0    Juan    26     Ibague
# 1   Pedro    56  Monterrey
# 2  Camilo    15     Bogota

# %%
df.head()
# Out:
#    Nombre  Edad     Ciudad
# 0    Juan    26     Ibague
# 1   Pedro    56  Monterrey
# 2  Camilo    15     Bogota

# %%
mayores= df[df['Edad'] > 25]
print(mayores)
# Out:
#   Nombre  Edad     Ciudad
# 0   Juan    26     Ibague
# 1  Pedro    56  Monterrey

# %%
#Calcular edad promedio
promedio_edad= df['Edad'].mean()
print(f'La edad promedio es: {promedio_edad}')
# Out:
# La edad promedio es: 32.333333333333336
